# %% [markdown]
# # Model comparison
# Using memote - the genome-scale metabolic model test suite, we compare four models. Make Y5 and Y8 models BiGG complaint.

# %%
from bigg_complaint import read_yeast_model, write_yeast_model

# %% [markdown]
# ## Yeast8

# %%
MODEL_PATH_Y8= "data/models/yeast-GEM.xml"

# %%
model_Y8 = read_yeast_model(MODEL_PATH_Y8)

# %%
write_yeast_model(model_Y8, "analysis/memote/model_Y8.xml")

# %% [markdown]
# ## Yeast 5

# %%
MODEL_PATH_Y5= "data/models/MODEL1209060000_url.xml"

# %%
model_Y5 = read_yeast_model(MODEL_PATH_Y5) #load original model
# Out:
# Model does not contain SBML fbc package information.
# SBML package 'layout' not supported by cobrapy, information is not parsed
# SBML package 'render' not supported by cobrapy, information is not parsed
# Adding exchange reaction EX_s_1826_b with default bounds for boundary metabolite: s_1826_b.
# Adding exchange reaction EX_s_1827_b with default bounds for boundary metabolite: s_1827_b.
# Adding exchange reaction EX_s_1828_b with default bounds for boundary metabolite: s_1828_b.
# Adding exchange reaction EX_s_1829_b with default bounds for boundary metabolite: s_1829_b.
# Adding exchange reaction EX_s_1830_b with default bounds for boundary metabolite: s_1830_b.
# Adding exchange reaction EX_s_1831_b with default bounds for boundary metabolite: s_1831_b.
# Adding exchange reaction EX_s_1832_b with default bounds for boundary metabolite: s_1832_b.
# Adding exchange reaction EX_s_1833_b with default bounds for boundary metabolite: s_1833_b.
# ...

# %%
write_yeast_model(model_Y5, "analysis/memote/model_Y5.xml")   #save BiGG complaint model

# %% [markdown]
# For running memote we used the following command from the terminal:
#
#
# memote report diff data/models/iMM904.xml data/models/iND750.xml model_Y5.xml model_Y8.xml
